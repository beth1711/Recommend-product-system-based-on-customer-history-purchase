# %%
# Import Python Packages
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from operator import attrgetter
# Out:
# /Users/thaonguyen/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Import the data
data = pd.read_excel("/Users/thaonguyen/Desktop/xin viec official/cty Long/CaseStudyData.xlsx")

# %%
data.head()
# Out:
#   InvoiceDate  Fiscal_Year  Ordernumber customercode Region   productcode  \
# 0  2021-07-01         2022      7481573       AAJ611     US   BRBON/BLA38
# 1  2021-07-01         2022      7481588       BBI349     US   BRBON/BLA28
# 2  2021-07-01         2022      7487131       BBH871     UK      ELEM/LP8
# 3  2021-07-01         2022      7487856       ALT905     UK    ABGOB.NON2
# 4  2021-07-01         2022      7487878       BBJ422     UK  MINI/SM/ARR2
#
#                                    ProductName ProductBrand  \
# 0  Blanton's Straight From the Barrel (65.15%)    Blanton's
# 1   Blanton's Straight From the Barrel (65.7%)    Blanton's
# 2       Lp8 - Elements of Islay / Madeira Cask    Laphroaig
# 3                             Ardbeg Uigeadail       Ardbeg
# 4                    Arran 10yo Malt Miniature        Arran
#
#   ProductPublishedDate                                 ProductDescription  \
# 0           2010-01-01  A single barrel bottling at 65.1% from Blanton...
# 1           2010-01-01  A single barrel bottling at 65.7% from Blanton...
# 2           2022-11-29  A spoonful of Madeira makes the medicine go do...
# 3           2010-01-01  A fine drop of Ardbeg bottled at cask strength...
# 4           2011-05-20  A miniature bottle of 10 year old whisky from ...
#
#                     Category                            SubCategory  \
# 0           American Whiskey              American Whiskey: Bourbon
# 1           American Whiskey              American Whiskey: Bourbon
# 2  Single Malt Scotch Whisky       Single Malt Scotch Whisky: Islay
# 3  Single Malt Scotch Whisky       Single Malt Scotch Whisky: Islay
# 4                 Miniatures  Miniatures: Single Malt Scotch Whisky
#
#    OldAndRareFlag Dimensions  Weight   Sales  Units   Price
# 0               0       70cl    1.92  104.17    1.0  104.17
# 1               0       70cl    1.92  104.17    1.0  104.17
# 2               1       50cl    1.25  145.84    1.0  145.84
# 3               0       70cl    2.00   49.96    1.0   49.96
# 4               0        5cl    0.25    4.13    1.0    4.13

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328069 entries, 0 to 328068
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   InvoiceDate           328069 non-null  datetime64[ns]
#  1   Fiscal_Year           328069 non-null  int64
#  2   Ordernumber           328069 non-null  int64
#  3   customercode          328069 non-null  object
#  4   Region                328069 non-null  object
#  5   productcode           328069 non-null  object
#  6   ProductName           328069 non-null  object
#  7   ProductBrand          328054 non-null  object
#  8   ProductPublishedDate  328069 non-null  datetime64[ns]
#  9   ProductDescription    326801 non-null  object
#  10  Category              328069 non-null  object
#  11  SubCategory           328069 non-null  object
#  12  OldAndRareFlag        328069 non-null  int64
#  13  Dimensions            322490 non-null  object
#  14  Weight                328069 non-null  float64
#  15  Sales                 328069 non-null  float64
#  16  Units                 327925 non-null  float64
#  17  Price                 327922 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(3), object(9)
# memory usage: 45.1+ MB

# %%
data['Ordernumber'].nunique()
# Out:
# 161427

# %%
data['customercode'].nunique()
# Out:
# 30629

# %% [markdown]
# ## Missing data
# Due to the data information, we can see that we have some missing value in Dimensions, Units, Price, Product Brand and Product Description.
#
# In term of filling missing data for each columns, my solutions to fill the missing data are:
# + Fill the missing price by the average (mean) of that product code in the non-missing rows
# + Calculate the missing data in Units column by Divide the sale of product to price and round them
# + For product brand, using the first letter of "Product Name" as the product brand
# + In terms of dimensions and Product Description, live the value as NaN when we can't fill the missing value

# %% [markdown]
# ### Fill null value in price and units

# %%
data['Price'].fillna(data.groupby('productcode')['Price'].transform('mean'), inplace=True)
data['Units'] = (data['Sales']/data['Price']).round(0)
data
# Out:
#        InvoiceDate  Fiscal_Year  Ordernumber customercode Region  \
# 0       2021-07-01         2022      7481573       AAJ611     US
# 1       2021-07-01         2022      7481588       BBI349     US
# 2       2021-07-01         2022      7487131       BBH871     UK
# 3       2021-07-01         2022      7487856       ALT905     UK
# 4       2021-07-01         2022      7487878       BBJ422     UK
# ...            ...          ...          ...          ...    ...
# 328064  2023-11-07         2024      8180815       AMV852     UK
# 328065  2023-11-07         2024      8181345       ADD567     UK
# 328066  2023-11-07         2024      8181346       ADF094     UK
# 328067  2023-11-07         2024      8181377       AAG403     UK
# 328068  2023-11-07         2024      8181456       AAB038     UK
#
#          productcode                                  ProductName  \
# 0        BRBON/BLA38  Blanton's Straight From the Barrel (65.15%)
# 1        BRBON/BLA28   Blanton's Straight From the Barrel (65.7%)
# 2           ELEM/LP8       Lp8 - Elements of Islay / Madeira Cask
# 3         ABGOB.NON2                             Ardbeg Uigeadail
# 4       MINI/SM/ARR2                    Arran 10yo Malt Miniature
# ...              ...                                          ...
# 328064    VERMO/APE3        The Aperitivo Co Turin Sweet Vermouth
# 328065    MONIN/HAZ1                         Monin Hazelnut Syrup
# 328066      RUM/RON1  Ron Zacapa Centenario Sistema Solera 23 Rum
# 328067      RUM/BAC1                     Bacardi Carta Blanca Rum
# 328068   BRBON/ELI17                     Elijah Craig Small Batch
#
#             ProductBrand ProductPublishedDate  \
# 0              Blanton's           2010-01-01
# 1              Blanton's           2010-01-01
# 2              Laphroaig           2022-11-29
# 3                 Ardbeg           2010-01-01
# 4                  Arran           2011-05-20
# ...                  ...                  ...
# 328064  The Aperitivo Co           2021-11-11
# 328065             Monin           2011-01-05
# 328066        Ron Zacapa           2022-02-03
# 328067           Bacardi           2010-01-01
# 328068      Elijah Craig           2017-09-25
#
#                                        ProductDescription  \
# 0       A single barrel bottling at 65.1% from Blanton...
# 1       A single barrel bottling at 65.7% from Blanton...
# 2       A spoonful of Madeira makes the medicine go do...
# 3       A fine drop of Ardbeg bottled at cask strength...
# 4       A miniature bottle of 10 year old whisky from ...
# ...                                                   ...
# 328064  A classically-styled Italian sweet vermouth fr...
# 328065  A marvellously nutty Monin syrup, with hints o...
# 328066  An awesome rum – winner of a Platinum medal an...
# 328067  The best-selling spirit brand worldwide, enjoy...
# 328068  The replacement for the hugely popular Elijah ...
#
#                          Category  \
# 0                American Whiskey
# 1                American Whiskey
# 2       Single Malt Scotch Whisky
# 3       Single Malt Scotch Whisky
# 4                      Miniatures
# ...                           ...
# 328064    Vermouths and Aperitifs
# 328065     Soft Drinks and Syrups
# 328066                        Rum
# 328067                        Rum
# 328068           American Whiskey
#
#                                              SubCategory  OldAndRareFlag  \
# 0                              American Whiskey: Bourbon               0
# 1                              American Whiskey: Bourbon               0
# 2                       Single Malt Scotch Whisky: Islay               1
# 3                       Single Malt Scotch Whisky: Islay               0
# 4                  Miniatures: Single Malt Scotch Whisky               0
# ...                                                  ...             ...
# 328064  Vermouths and Aperitifs: Vermouths and Aperitifs               0
# 328065         Soft Drinks and Syrups: Syrups and Purées               0
# 328066                                       Rum: Golden               0
# 328067                                        Rum: White               0
# 328068                         American Whiskey: Bourbon               0
#
#        Dimensions  Weight   Sales  Units    Price
# 0            70cl    1.92  104.17    1.0  104.170
# 1            70cl    1.92  104.17    1.0  104.170
# 2            50cl    1.25  145.84    1.0  145.840
# 3            70cl    2.00   49.96    1.0   49.960
# 4             5cl    0.25    4.13    1.0    4.130
# ...           ...     ...     ...    ...      ...
# 328064       75cl    1.49   19.96    1.0   19.960
# 328065       70cl    1.49    7.95    1.0    7.950
# 328066       70cl    2.00   47.46    1.0   47.460
# 328067       70cl    1.49   66.50    4.0   16.625
# 328068       70cl    1.50   37.08    1.0   37.080
#
# [328069 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328069 entries, 0 to 328068
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   InvoiceDate           328069 non-null  datetime64[ns]
#  1   Fiscal_Year           328069 non-null  int64
#  2   Ordernumber           328069 non-null  int64
#  3   customercode          328069 non-null  object
#  4   Region                328069 non-null  object
#  5   productcode           328069 non-null  object
#  6   ProductName           328069 non-null  object
#  7   ProductBrand          328069 non-null  object
#  8   ProductPublishedDate  328069 non-null  datetime64[ns]
#  9   ProductDescription    326801 non-null  object
#  10  Category              328069 non-null  object
#  11  SubCategory           328069 non-null  object
#  12  OldAndRareFlag        328069 non-null  int64
#  13  Dimensions            322490 non-null  object
#  14  Weight                328069 non-null  float64
#  15  Sales                 328069 non-null  float64
#  16  Units                 328069 non-null  float64
#  17  Price                 328069 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(3), object(9)
# memory usage: 45.1+ MB

# %%
data['ProductBrand'].fillna(data['ProductName'].str.split(' ').str[0], inplace = True)

# %%
#Save the data to file csv
data.to_csv('Clean_data.csv', index=False)

# %%
#Group by the order data to analyse
order_data = data.groupby(['customercode','Region','Ordernumber'])['Sales'].agg('sum').reset_index(['customercode','Region','Ordernumber'])
order_data
# Out:
#        customercode Region  Ordernumber   Sales
# 0               409     UK      7495495  108.25
# 1               409     UK      7510928  195.83
# 2               409     UK      7532757  208.33
# 3               409     UK      7754873   62.46
# 4               409     UK      7827091  165.83
# ...             ...    ...          ...     ...
# 161422       WEBDK4     EU      8135824   45.63
# 161423       WEBDK4     EU      8143088   22.70
# 161424       WEBDK4     EU      8147808   57.29
# 161425       WEBDK4     EU      8151561  232.88
# 161426       WEBDK4     EU      8157102  176.67
#
# [161427 rows x 4 columns]

# %%
customer_data = order_data.groupby(['Region','customercode'])['Sales'].agg('sum').reset_index(['Region','customercode'])
customer_data['count'] = customer_data['customercode'].map(order_data['customercode'].value_counts())
customer_data['AoV'] = customer_data['Sales']/customer_data['count']
customer_data
# Out:
#       Region customercode     Sales  count         AoV
# 0       ASIA         2591  12671.80     16  791.987500
# 1       ASIA       AAA060  13555.47     19  713.445789
# 2       ASIA       AAA240   3032.50      4  758.125000
# 3       ASIA       AAA280   3604.80      7  514.971429
# 4       ASIA       AAA327   1724.05      5  344.810000
# ...      ...          ...       ...    ...         ...
# 31088     US       BOM822    826.92      3  275.640000
# 31089     US       BON799   2979.18      4  744.795000
# 31090     US       BOO480    281.84      3   93.946667
# 31091     US       BOP984   1453.32      3  484.440000
# 31092     US       BOU195    741.60      3  247.200000
#
# [31093 rows x 5 columns]

# %%
def func(row):
    if row['count'] >= 5 and row['AoV'] >= 148:
        return 'HighValue_Loyal'
    elif row['count'] >= 5 and row['AoV'] < 148:
        return 'LowValue_Loyal' 
    elif row['count'] < 5 and row['AoV'] >= 148:
        return 'HighValue_NoLoyal' 
    else:
        return 'LowValue_NoLoyal'

customer_data['customer_type'] = customer_data.apply(func, axis=1)
customer_data
# Out:
#       Region customercode     Sales  count         AoV      customer_type
# 0       ASIA         2591  12671.80     16  791.987500    HighValue_Loyal
# 1       ASIA       AAA060  13555.47     19  713.445789    HighValue_Loyal
# 2       ASIA       AAA240   3032.50      4  758.125000  HighValue_NoLoyal
# 3       ASIA       AAA280   3604.80      7  514.971429    HighValue_Loyal
# 4       ASIA       AAA327   1724.05      5  344.810000    HighValue_Loyal
# ...      ...          ...       ...    ...         ...                ...
# 31088     US       BOM822    826.92      3  275.640000  HighValue_NoLoyal
# 31089     US       BON799   2979.18      4  744.795000  HighValue_NoLoyal
# 31090     US       BOO480    281.84      3   93.946667   LowValue_NoLoyal
# 31091     US       BOP984   1453.32      3  484.440000  HighValue_NoLoyal
# 31092     US       BOU195    741.60      3  247.200000  HighValue_NoLoyal
#
# [31093 rows x 6 columns]

# %%
customer_data.to_csv("customer_data1.csv", index=False)

# %%
customer_data['Sales'].describe()
# Out:
# count     31093.000000
# mean       1045.430756
# std        7712.407287
# min           7.920000
# 25%         195.880000
# 50%         366.310000
# 75%         759.180000
# max      828710.250000
# Name: Sales, dtype: float64

# %%
customer_data['count'].describe()
# Out:
# count    31093.000000
# mean         5.315634
# std         12.256844
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max       1319.000000
# Name: count, dtype: float64

# %%
customer_data['AoV'].describe()
# Out:
# count    31093.000000
# mean       173.032525
# std        647.350259
# min          0.592500
# 25%         53.210000
# 50%         89.552500
# 75%        148.710000
# max      55205.000000
# Name: AoV, dtype: float64

# %%
import numpy as np
np.percentile(customer_data['count'], 90)
# Out:
# 9.0

# %%
np.percentile(customer_data['Sales'], 95)
# Out:
# 3019.211999999998

# %%
np.percentile(customer_data['AoV'], 90)
# Out:
# 295.65915501519754

# %%
order_data_region = order_data.groupby('Region')['Sales'].agg(['count','sum']).reset_index()
order_data_region['AoV'] = order_data_region['sum']/order_data_region['count']
order_data_region
# Out:
#   Region   count          sum         AoV
# 0   ASIA    8512   5782294.69  679.310936
# 1     EU    4209   2019098.00  479.709670
# 2    ROW    1258    583348.77  463.711264
# 3     UK  139655  20006300.41  143.255167
# 4     US    7793   4114536.62  527.978522

# %%
returner = order_data.groupby(['Region','customercode'])['Ordernumber'].agg('count').reset_index(name = 'number_purchase')
returner
# Out:
#       Region customercode  number_purchase
# 0       ASIA         2591               16
# 1       ASIA       AAA060               19
# 2       ASIA       AAA240                2
# 3       ASIA       AAA280                7
# 4       ASIA       AAA327                5
# ...      ...          ...              ...
# 31088     US       BOM822                3
# 31089     US       BON799                4
# 31090     US       BOO480                3
# 31091     US       BOP984                3
# 31092     US       BOU195                3
#
# [31093 rows x 3 columns]

# %%
returner1 = returner.groupby('Region')['number_purchase'].agg('sum').reset_index(name = 'total')
returner1
# Out:
#   Region   total
# 0   ASIA    8512
# 1     EU    4209
# 2    ROW    1258
# 3     UK  139655
# 4     US    7793

# %%
returner2 = returner.groupby('Region')['customercode'].agg('count').reset_index(name = 'customer_total')
returner2
# Out:
#   Region  customer_total
# 0   ASIA            1504
# 1     EU             411
# 2    ROW             275
# 3     UK           27198
# 4     US            1705

# %%
returner1['Average_return'] = returner1['total']/returner2['customer_total']
returner1
# Out:
#   Region   total  Average_return
# 0   ASIA    8512        5.659574
# 1     EU    4209       10.240876
# 2    ROW    1258        4.574545
# 3     UK  139655        5.134753
# 4     US    7793        4.570674

# %%
fig = plt.figure(figsize =(1, 3))
plt.boxplot(returner['number_purchase'])
plt.show()

# %%
returner['number_purchase'].describe()
# Out:
# count    31093.000000
# mean         5.191747
# std         12.038398
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max       1319.000000
# Name: number_purchase, dtype: float64

# %%
product_data = data.groupby(['productcode','Dimensions' ])['Ordernumber'].agg('count').reset_index(['productcode','Dimensions'])
product_data
# Out:
#         productcode Dimensions  Ordernumber
# 0        ABFCOP2015       70cl            1
# 1        ABFFF.15YO       70cl            3
# 2      ABFFF.15YOV1       70cl            1
# 3        ABFFF.1980       70cl            1
# 4        ABFGLM2005       70cl            2
# ...             ...        ...          ...
# 18382  WINE/ZEP2020       75cl           10
# 18383  WINE/ZEP2022       75cl            6
# 18384  WINE/ZIN2018       75cl           10
# 18385  WINE/ZUS2016       75cl            3
# 18386  WINE/ZUS2020       75cl            1
#
# [18387 rows x 3 columns]

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18387 entries, 0 to 18386
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   productcode  18387 non-null  object
#  1   Dimensions   18387 non-null  object
#  2   Ordernumber  18387 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 431.1+ KB

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format='%m/%d/%Y %H:%M')
data['order_quarter'] = data['InvoiceDate'].dt.to_period('Q')
data['cohort'] = data.groupby('customercode')['InvoiceDate'].transform('min').dt.to_period('Q')

# %%
data_cohort = data.groupby(['cohort', 'order_quarter']).agg(n_customers=('customercode', 'nunique')).reset_index(drop=False)
data_cohort['period_number'] = (data_cohort['order_quarter'] - data_cohort['cohort']).apply(attrgetter('n'))
data_cohort
# Out:
#     cohort order_quarter  n_customers  period_number
# 0   2021Q3        2021Q3        10488              0
# 1   2021Q3        2021Q4         6523              1
# 2   2021Q3        2022Q1         3949              2
# 3   2021Q3        2022Q2         3947              3
# 4   2021Q3        2022Q3         4218              4
# 5   2021Q3        2022Q4         4724              5
# 6   2021Q3        2023Q1         3037              6
# 7   2021Q3        2023Q2         2880              7
# 8   2021Q3        2023Q3         3161              8
# 9   2021Q3        2023Q4         1439              9
# 10  2021Q4        2021Q4        10684              0
# 11  2021Q4        2022Q1         3304              1
# 12  2021Q4        2022Q2         3422              2
# 13  2021Q4        2022Q3         2841              3
# 14  2021Q4        2022Q4         5841              4
# 15  2021Q4        2023Q1         2527              5
# 16  2021Q4        2023Q2         2515              6
# 17  2021Q4        2023Q3         2100              7
# 18  2021Q4        2023Q4         1419              8
# 19  2022Q1        2022Q1         2553              0
# 20  2022Q1        2022Q2          988              1
# 21  2022Q1        2022Q3          893              2
# 22  2022Q1        2022Q4         1117              3
# 23  2022Q1        2023Q1          922              4
# 24  2022Q1        2023Q2          638              5
# 25  2022Q1        2023Q3          583              6
# 26  2022Q1        2023Q4          323              7
# 27  2022Q2        2022Q2         1941              0
# 28  2022Q2        2022Q3          796              1
# 29  2022Q2        2022Q4         1024              2
# 30  2022Q2        2023Q1          623              3
# 31  2022Q2        2023Q2          745              4
# 32  2022Q2        2023Q3          496              5
# 33  2022Q2        2023Q4          262              6
# 34  2022Q3        2022Q3         1626              0
# 35  2022Q3        2022Q4          929              1
# 36  2022Q3        2023Q1          599              2
# 37  2022Q3        2023Q2          546              3
# 38  2022Q3        2023Q3          627              4
# 39  2022Q3        2023Q4          231              5
# 40  2022Q4        2022Q4         1834              0
# 41  2022Q4        2023Q1          834              1
# 42  2022Q4        2023Q2          682              2
# 43  2022Q4        2023Q3          614              3
# 44  2022Q4        2023Q4          385              4
# 45  2023Q1        2023Q1          763              0
# 46  2023Q1        2023Q2          482              1
# 47  2023Q1        2023Q3          357              2
# 48  2023Q1        2023Q4          192              3
# 49  2023Q2        2023Q2          469              0
# 50  2023Q2        2023Q3          324              1
# 51  2023Q2        2023Q4          155              2
# 52  2023Q3        2023Q3          244              0
# 53  2023Q3        2023Q4          126              1
# 54  2023Q4        2023Q4           27              0

# %% [markdown]
# ### Visualise the cohort: customer retention

# %%
cohort_pivot = data_cohort.pivot_table(index='cohort', columns='period_number', values='n_customers')
cohort_size = cohort_pivot.iloc[:, 0]
retention_matrix = cohort_pivot.divide(cohort_size, axis=0)

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    # retention matrix
    sns.heatmap(retention_matrix, 
                mask=retention_matrix.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='RdYlGn', 
                ax=ax[1])
    ax[1].set_title('Quarterly Cohorts: User Retention', fontsize=16)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    # cohort size
    cohort_size_df = pd.DataFrame(cohort_size).rename(columns={0: 'cohort_size'})
    white_cmap = mcolors.ListedColormap(['white'])
    sns.heatmap(cohort_size_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()

# %% [markdown]
# # Machine learning model to recommend product for exisiting customer

# %%
import pandas as pd
import numpy as np
import random
from tqdm import tqdm
from gensim.models import Word2Vec 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings;
warnings.filterwarnings('ignore')

# %%
df = data[['customercode', 'Ordernumber', 'Units','OldAndRareFlag','productcode','ProductDescription','ProductName','InvoiceDate','Region', 'Price']]
df
# Out:
#        customercode  Ordernumber  Units  OldAndRareFlag   productcode  \
# 0            AAJ611      7481573    1.0               0   BRBON/BLA38
# 1            BBI349      7481588    1.0               0   BRBON/BLA28
# 2            BBH871      7487131    1.0               1      ELEM/LP8
# 3            ALT905      7487856    1.0               0    ABGOB.NON2
# 4            BBJ422      7487878    1.0               0  MINI/SM/ARR2
# ...             ...          ...    ...             ...           ...
# 328064       AMV852      8180815    1.0               0    VERMO/APE3
# 328065       ADD567      8181345    1.0               0    MONIN/HAZ1
# 328066       ADF094      8181346    1.0               0      RUM/RON1
# 328067       AAG403      8181377    4.0               0      RUM/BAC1
# 328068       AAB038      8181456    1.0               0   BRBON/ELI17
#
#                                        ProductDescription  \
# 0       A single barrel bottling at 65.1% from Blanton...
# 1       A single barrel bottling at 65.7% from Blanton...
# 2       A spoonful of Madeira makes the medicine go do...
# 3       A fine drop of Ardbeg bottled at cask strength...
# 4       A miniature bottle of 10 year old whisky from ...
# ...                                                   ...
# 328064  A classically-styled Italian sweet vermouth fr...
# 328065  A marvellously nutty Monin syrup, with hints o...
# 328066  An awesome rum – winner of a Platinum medal an...
# 328067  The best-selling spirit brand worldwide, enjoy...
# 328068  The replacement for the hugely popular Elijah ...
#
#                                         ProductName InvoiceDate Region  \
# 0       Blanton's Straight From the Barrel (65.15%)  2021-07-01     US
# 1        Blanton's Straight From the Barrel (65.7%)  2021-07-01     US
# 2            Lp8 - Elements of Islay / Madeira Cask  2021-07-01     UK
# 3                                  Ardbeg Uigeadail  2021-07-01     UK
# 4                         Arran 10yo Malt Miniature  2021-07-01     UK
# ...                                             ...         ...    ...
# 328064        The Aperitivo Co Turin Sweet Vermouth  2023-11-07     UK
# 328065                         Monin Hazelnut Syrup  2023-11-07     UK
# 328066  Ron Zacapa Centenario Sistema Solera 23 Rum  2023-11-07     UK
# 328067                     Bacardi Carta Blanca Rum  2023-11-07     UK
# 328068                     Elijah Craig Small Batch  2023-11-07     UK
#
#           Price
# 0       104.170
# 1       104.170
# 2       145.840
# 3        49.960
# 4         4.130
# ...         ...
# 328064   19.960
# 328065    7.950
# 328066   47.460
# 328067   16.625
# 328068   37.080
#
# [328069 rows x 10 columns]

# %%
# remove missing values
df.dropna(inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326801 entries, 0 to 328068
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customercode        326801 non-null  object
#  1   Ordernumber         326801 non-null  int64
#  2   Units               326801 non-null  float64
#  3   OldAndRareFlag      326801 non-null  int64
#  4   productcode         326801 non-null  object
#  5   ProductDescription  326801 non-null  object
#  6   ProductName         326801 non-null  object
#  7   InvoiceDate         326801 non-null  datetime64[ns]
#  8   Region              326801 non-null  object
#  9   Price               326801 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 27.4+ MB

# %%
customers = df["customercode"].unique().tolist()
len(customers)
# Out:
# 30628

# %%
random.shuffle(customers)

# extract 90% of customer ID's
customers_train = [customers[i] for i in range(round(0.9*len(customers)))]

# split data into train and validation set
train_df = df[df['customercode'].isin(customers_train)]
validation_df = df[~df['customercode'].isin(customers_train)]

# %%
# list to capture purchase history of the customers
purchases_train = []

# populate the list with the product codes
for i in tqdm(customers_train):
    temp = train_df[train_df["customercode"] == i]["productcode"].tolist()
    purchases_train.append(temp)
# Out:
# 100%|█████████████████████████████████████| 27565/27565 [07:31<00:00, 61.11it/s]

# %%
purchases_val = []
customer_code = {}
        
# populate the list with the product codes
for customer_id in tqdm(validation_df['customercode'].unique()):
    temp = validation_df[validation_df["customercode"] == customer_id]["productcode"].tolist()
    purchases_val.append(temp)
    if customer_id not in customer_code:
        customer_code[customer_id] = []
    customer_code[customer_id].append(validation_df[validation_df['customercode'] == customer_id]['productcode'].tolist())
# Out:
# 100%|██████████████████████████████████████| 3063/3063 [00:11<00:00, 264.22it/s]

# %%
for key, value in customer_code.items():
    flattened_products = [product for sublist in value for product in sublist]
    customer_code[key] = flattened_products

# %% [markdown]
# ### Build word2vec Embeddings for Products

# %%
# train word2vec model
model = Word2Vec(window = 10, sg = 1, hs = 0,
                 negative = 10, # for negative sampling
                 alpha=0.03, min_alpha=0.0007,
                 seed = 14)

model.build_vocab(purchases_train, progress_per=200)

model.train(purchases_train, total_examples = model.corpus_count, 
            epochs=10, report_delay=1)
# Out:
# (2775546, 2958190)

# %%
# save word2vec model
model.save("word2vec_2.model")

# %%
model.init_sims(replace=True)
print(model)
# Out:
# Word2Vec(vocab=9566, vector_size=100, alpha=0.03)

# %%
model.init_sims(replace=True)
X = model.wv.vectors
vocabulary = model.wv.index_to_key

# %%
products = train_df[["productcode", "ProductName"]]

# remove duplicates
products.drop_duplicates(inplace=True, subset='productcode', keep="last")

# create product-ID and product-description dictionary
products_dict = products.groupby('productcode')['ProductName'].apply(list).to_dict()

# %%
products_dict['ELEM/LP8']
# Out:
# ['Lp8 - Elements of Islay / Madeira Cask']

# %%
def similar_products(v, n = 6):
    
    # extract most similar products for the input vector
    ms = model.wv.similar_by_vector(v, topn= n+1)[1:]
    
    # extract name and similarity score of the similar products
    new_ms = []
    for j in ms:
        pair = (products_dict[j[0]][0], j[1])
        new_ms.append(pair)
        
    return new_ms

# %%
# similar_products('VERMO/APE3')

similar_products(model.wv['VERMO/APE3'])
# Out:
# [('Fee Brothers Celery Bitters', 0.6872725486755371),
#  ('Monin Basil', 0.6848461627960205),
#  ('Karminia Rosso Vermouth di Torino', 0.6772699356079102),
#  ('El Bandara Al Fresco Aperitif', 0.6681668162345886),
#  ('Batanga Tequila Duo / 2 Bottles', 0.6666544079780579),
#  ('Bach Highball / Crystal / Luigi Bormioli', 0.6608810424804688)]

# %%
def aggregate_vectors(products):
    product_vec = []
    for i in products:
        try:
            product_vec.append(model.wv[i])
        except KeyError:
            continue
        
    return np.mean(product_vec, axis=0)

# %%
similar_products(aggregate_vectors(customer_code['AAD612']))
# Out:
# [("Re'al Cream of Coconut", 0.9417122006416321),
#  ('Monin Orange Syrup', 0.9389959573745728),
#  ('Monin Chestnut (Chataigne)', 0.9386228919029236),
#  ('Monin Blueberry Puree / Litre', 0.9351627826690674),
#  ('Monin Lemon Syrup', 0.9346762895584106),
#  ('Monin Strawberry BonBon Syrup', 0.9336432814598083)]
